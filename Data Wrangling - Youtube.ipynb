# %%
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime
import time
import isodate
import requests
from bs4 import BeautifulSoup

# %%
df['tags'].map(lambda x: x.strip('][').replace('\'','').split(', '),na_action='ignore').map(len,na_action='ignore')
# Out:
# 0         26.0
# 1         30.0
# 2         13.0
# 3         19.0
# 4         21.0
#           ...
# 387376    12.0
# 387377     7.0
# 387378     2.0
# 387379    55.0
# 387380    30.0
# Name: tags, Length: 387381, dtype: float64

# %%
df.value_counts('liveBroadcastContent')
# Out:
# liveBroadcastContent
# none        386984
# live           337
# upcoming        60
# dtype: int64

# %%
a = df['parseDate'].astype('datetime64[ns]')

# %%
b = df['publishedAt'].astype('datetime64[ns]')

# %%
c= a-b

# %%
combined_videos = pd.concat([pd.read_csv('videos_df.csv'), pd.read_csv('videos_df2.csv') ])

# %%
combined_channels = pd.concat([pd.read_csv('channels_df.csv'), pd.read_csv('channels_df2.csv') ])

# %%
df = pd.read_csv('videos.csv')

# %%
len(df)
# Out:
# 694138

# %%
len(combined_channels)
# Out:
# 824136

# %%
len(combined_channels)
# Out:
# 818925

# %%
df['id'].nunique()
# Out:
# 694138

# %%
combined_channels['id'].nunique()
# Out:
# 288567

# %%
combined_channels = combined_channels.drop_duplicates('id',keep='last')

# %%
combined = pd.merge(left=combined_videos, right=combined_channels, how='left', left_on='channelId', right_on='id')

# %%
len(combined)
# Out:
# 571923

# %%
combined_channels.shape
# Out:
# (248996, 18)

# %%
combined_channels['id'].nunique()
# Out:
# 248996

# %%
combined_videos.shape
# Out:
# (571923, 24)

# %%
combined_videos = combined_videos.drop_duplicates('id',keep='last')

# %%
len(combined_videos)
# Out:
# 694138

# %%
len(combined_channels)
# Out:
# 288567

# %%
combined_videos['id'].nunique()
# Out:
# 694138

# %%
combined_channels['id'].nunique()
# Out:
# 288567

# %%
combined_channels['subscriberCount'].describe()
# Out:
# count    2.885670e+05
# mean     1.804920e+05
# std      1.164376e+06
# min      0.000000e+00
# 25%      1.830000e+02
# 50%      2.990000e+03
# 75%      3.810000e+04
# max      1.530000e+08
# Name: subscriberCount, dtype: float64

# %%
a=combined_videos['viewCount']<25000
b=combined_videos['viewCount']>1000000
#combined_videos['likeCount'].hist()
pd.qcut(combined_videos['viewCount'][b], 4).value_counts()
# Out:
# (1000000.999, 1781699.0]     38292
# (9918316.0, 6968233196.0]    38291
# (3606583.0, 9918316.0]       38291
# (1781699.0, 3606583.0]       38291
# Name: viewCount, dtype: int64

# %%
combined_videos[a]['categoryId'].value_counts()
# Out:
# 27    69315
# 22    59812
# 25    22739
# 10    19416
# 24    19034
# 28    15546
# 1     11278
# 20    10306
# 19     9352
# 26     8603
# 29     6508
# 17     5933
# 2      2948
# 23     2716
# 15     2565
# 44      120
# Name: categoryId, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 694138 entries, 0 to 694137
# Data columns (total 25 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            694138 non-null  int64
#  1   Unnamed: 0.1          694138 non-null  int64
#  2   parseDate             694138 non-null  object
#  3   id                    694138 non-null  object
#  4   channelId             694138 non-null  object
#  5   channelTitle          694103 non-null  object
#  6   title                 694138 non-null  object
#  7   description           662143 non-null  object
#  8   tags                  601632 non-null  object
#  9   categoryId            694138 non-null  int64
#  10  liveBroadcastContent  694138 non-null  object
#  11  publishedAt           694138 non-null  object
#  12  defaultAudioLanguage  334110 non-null  object
#  13  duration              694138 non-null  object
# ...

# %%
df.drop(df.columns[[0,1,10,14,22]], axis = 1,inplace=True)

# %%
df = df.reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 694138 entries, 0 to 694137
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   parseDate             694138 non-null  object
#  1   id                    694138 non-null  object
#  2   channelId             694138 non-null  object
#  3   channelTitle          694103 non-null  object
#  4   title                 694138 non-null  object
#  5   description           662143 non-null  object
#  6   tags                  601632 non-null  object
#  7   categoryId            694138 non-null  int64
#  8   publishedAt           694138 non-null  object
#  9   defaultAudioLanguage  334110 non-null  object
#  10  duration              694138 non-null  object
#  11  definition            694138 non-null  object
#  12  caption               694138 non-null  bool
#  13  licensedContent       694138 non-null  bool
# ...

# %%
df['parseDate'] = df['parseDate'].astype('datetime64[ns]') 
df['publishedAt'] = df['publishedAt'].astype('datetime64[ns]')

# %%
df['tags'] = df['tags'].map(lambda x: x.strip('][').replace('\'','').split(', '),na_action='ignore')

# %%
df['relevantTopicIds'][]
# Out:
# 0                                              ['/m/04rlf']
# 1                                  ['/m/04rlf', '/m/04rlf']
# 2         ['/m/02jjt', '/m/05qjc', '/m/02jjt', '/m/05qjc...
# 3                                                       NaN
# 4                                ['/m/01k8wb', '/m/01k8wb']
#                                 ...
# 694133    ['/m/02jjt', '/m/0f2f9', '/m/09kqc', '/m/02jjt...
# 694134     ['/m/06bvp', '/m/098wr', '/m/098wr', '/m/06bvp']
# 694135    ['/m/04rlf', '/m/0glt670', '/m/04rlf', '/m/0gl...
# 694136                                         ['/m/02jjt']
# 694137                                                  NaN
# Name: relevantTopicIds, Length: 694138, dtype: object

# %%
combined_videos.head(10)
# Out:
#                      parseDate           id                 channelId  \
# 408 2020-09-11 15:17:26.898408  gi31zUVmTMk  UCCgCK4HAhzjD3IFw9cdXuOw
# 415 2020-09-11 15:17:26.898408  ZF-m_85NhkI  UCkUgsn09KF0dRBfmiwwOhuw
# 418 2020-09-11 15:17:26.898408  rF3Pm1H-9Cw  UCib3eicH-l1zd8JvXlrgZBQ
# 420 2020-09-11 15:17:26.898408  fxU_eYqiZyY  UC0hDbqQceq3Taouih7vOL9g
# 426 2020-09-11 15:17:26.898408  gy3ocXB-Kyk  UCPZc6ch0tOut9OO8NG2GkDA
# 427 2020-09-11 15:17:26.898408  5BbwiWVykuk  UCvR9mfF4U1KZVQOJW9ERmLw
# 430 2020-09-11 15:17:26.898408  hhqdl5WVLU0  UCkdjN3kH9rEnhwfBbWfCMWw
# 432 2020-09-11 15:17:26.898408  WskpbZARCYU  UCAQVxFpC0FvmqH5NRgKqxKw
# 433 2020-09-11 15:17:26.898408  _S_1BVuj42U  UCeDWSU6jSXXxYjFdmgzQOHw
# 439 2020-09-11 15:17:26.898408  RfAjkLppxfg  UCBH9eSxMrVNidpBGVTl_-Bw
#
#                          channelTitle  \
# 408                             Wiara
# 415  Miracle Vell Magic avex official
# 418                           boxgame
# 420                              HTTV
# ...

# %%
combined_videos['duration'][333:340]
# Out:
# 2242       PT4M25S
# 2243     PT1H58M5S
# 2244      PT12M17S
# 2245        PT4M3S
# 2246      PT48M30S
# 2247    PT1H34M24S
# 2249       PT3M10S
# Name: duration, dtype: object

# %%
isodate.parse_duration(combined_videos['duration'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-dabf477d45a5> in <module>
# ----> 1 isodate.parse_duration(combined_videos['duration'])
#
# NameError: name 'combined_videos' is not defined

# %%
z = (datetime.strptime('PT46S', r'PT[%MM]?%SS') - datetime.strptime("0", "%S")).total_seconds()/60
z
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-171-f0fef0291bdb> in <module>
# ----> 1 z = (datetime.strptime('PT46S', r'PT[%MM]?%SS') - datetime.strptime("0", "%S")).total_seconds()/60
#       2 z
#
# ~\anaconda3\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# ~\anaconda3\lib\_strptime.py in _strptime(data_string, format)
#     357     if not found:
#     358         raise ValueError("time data %r does not match format %r" %
# --> 359                          (data_string, format))
#     360     if len(data_string) != found.end():
# ...

# %%
combined_channels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 288567 entries, 338 to 425225
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             288567 non-null  int64
#  1   parseDate              288567 non-null  object
#  2   id                     288567 non-null  object
#  3   title                  288566 non-null  object
#  4   description            203429 non-null  object
#  5   publishedAt            288566 non-null  object
#  6   country                156412 non-null  object
#  7   madeForKids            106707 non-null  object
#  8   keywords               161699 non-null  object
#  9   showRelatedChannels    259776 non-null  object
#  10  featuredChannelsUrls   87180 non-null   float64
#  11  profileColor           288567 non-null  object
#  12  viewCount              288567 non-null  int64
#  13  subscriberCount        288567 non-null  int64
# ...

# %%
combined_channels.drop(combined_channels.columns[[0,16]], axis = 1,inplace=True)
combined_channels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 288567 entries, 338 to 425225
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   parseDate              288567 non-null  object
#  1   id                     288567 non-null  object
#  2   title                  288566 non-null  object
#  3   description            203429 non-null  object
#  4   publishedAt            288566 non-null  object
#  5   country                156412 non-null  object
#  6   madeForKids            106707 non-null  object
#  7   keywords               161699 non-null  object
#  8   showRelatedChannels    259776 non-null  object
#  9   featuredChannelsUrls   87180 non-null   float64
#  10  profileColor           288567 non-null  object
#  11  viewCount              288567 non-null  int64
#  12  subscriberCount        288567 non-null  int64
#  13  hiddenSubscriberCount  288567 non-null  bool
# ...

# %%
combined_videos['defaultAudioLanguage'].value_counts()
# Out:
# en       194273
# en-US     37866
# en-GB     36002
# hi        19461
# zxx        4631
#           ...
# lb            1
# fr-CH         1
# st            1
# ia            1
# ay            1
# Name: defaultAudioLanguage, Length: 167, dtype: int64

# %%
pd.qcut(combined_channels['subscriberCount'][combined_channels['subscriberCount']>100000], q=4).value_counts()
# Out:
# (100999.999, 177000.0]     12302
# (343000.0, 845000.0]       12239
# (845000.0, 153000000.0]    12222
# (177000.0, 343000.0]       12161
# Name: subscriberCount, dtype: int64

# %%
combined_videos['viewCount'].describe()
# Out:
# count    6.939880e+05
# mean     4.146360e+06
# std      4.221292e+07
# min      0.000000e+00
# 25%      4.608000e+03
# 50%      1.003610e+05
# 75%      7.563005e+05
# max      6.968233e+09
# Name: viewCount, dtype: float64

# %%
combined['id_x'].nunique()
# Out:
# 544023

# %%
combined = combined.drop_duplicates('id_x')

# %%
len(combined)
# Out:
# 544023

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 544023 entries, 0 to 571922
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0_x           544023 non-null  int64
#  1   parseDate_x            544023 non-null  object
#  2   id_x                   544023 non-null  object
#  3   channelId              544023 non-null  object
#  4   channelTitle           543991 non-null  object
#  5   title_x                544023 non-null  object
#  6   description_x          515136 non-null  object
#  7   tags                   462633 non-null  object
#  8   categoryId             544023 non-null  int64
#  9   liveBroadcastContent   544023 non-null  object
#  10  publishedAt_x          544023 non-null  object
#  11  defaultAudioLanguage   252860 non-null  object
#  12  duration               544023 non-null  object
#  13  dimension              544023 non-null  object
# ...

# %%
combined.drop(combined.columns[[0,3,4,24]], axis = 1,inplace=True)

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 544023 entries, 0 to 571922
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   parseDate_x            544023 non-null  object
#  1   id_x                   544023 non-null  object
#  2   title_x                544023 non-null  object
#  3   description_x          515136 non-null  object
#  4   tags                   462633 non-null  object
#  5   categoryId             544023 non-null  int64
#  6   liveBroadcastContent   544023 non-null  object
#  7   publishedAt_x          544023 non-null  object
#  8   defaultAudioLanguage   252860 non-null  object
#  9   duration               544023 non-null  object
#  10  dimension              544023 non-null  object
#  11  definition             544023 non-null  object
#  12  caption                544023 non-null  bool
#  13  licensedContent        544023 non-null  bool
# ...

# %%
combined.to_csv('combined.csv')

# %%
combined_videos.to_csv('videos.csv')

# %%
combined_channels.to_csv('channels.csv')

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(combined_videos,explorative=True,minimal=True)

# %%
profile.to_notebook_iframe()
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.8.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-09-19 07:25:39.817090&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
cprofile = ProfileReport(combined_channels,explorative=True,minimal=True)
cprofile.to_notebook_iframe()
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.8.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-09-19 07:35:51.728783&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
combined['viewCount_x'].mean()
# Out:
# 3528385.344742247

# %%
combined['viewCount_x'].quantile(0.8)
# Out:
# 580115.0000000002

# %%
combined['viewCount_x'][combined['viewCount_x']<1000].count()
# Out:
# 107413

# %%
r = requests.get('https://gist.github.com/stpe/2951130dfc8f1d0d1a2ad736bef3b703')
r.text
soup=BeautifulSoup(r.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-40b82ef87a50bc7574d05ba786c077b9.css" integrity="sha512-QLgu+HpQvHV00FunhsB3ueQCfgM7dkyMXKp1BrwCifVinFow2alu90jbiIbSdyn4/rXsaRo3otCqeYgmRmTCEA==" media="all" rel="stylesheet">
# ...

# %%
topictags = {}
for i in soup.find_all('ul')[1:7]:
    for j in i.find_all('li'):
        topictags[j.text.split(' ',1)[0]] = j.text.split(' ',1)[1].strip()

# %%
topictags['/m/02wbm']
# Out:
# 'Food'
